# %% [markdown]
# <a href="https://colab.research.google.com/github/mvarentsov/UClim4HSE-2026/blob/main/scripts/grib_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install eccodes
# !pip install cfgrib
# Out:
# Requirement already satisfied: eccodes in /usr/local/lib/python3.12/dist-packages (2.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from eccodes) (2.0.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from eccodes) (25.4.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from eccodes) (2.0.0)
# Requirement already satisfied: findlibs in /usr/local/lib/python3.12/dist-packages (from eccodes) (0.1.2)
# Requirement already satisfied: eccodeslib in /usr/local/lib/python3.12/dist-packages (from eccodes) (2.46.0.13)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->eccodes) (3.0)
# Requirement already satisfied: eckitlib==2.0.1.13 in /usr/local/lib/python3.12/dist-packages (from eccodeslib->eccodes) (2.0.1.13)
# Requirement already satisfied: fckitlib==0.14.2.13 in /usr/local/lib/python3.12/dist-packages (from eccodeslib->eccodes) (0.14.2.13)
# Requirement already satisfied: cfgrib in /usr/local/lib/python3.12/dist-packages (0.9.15.1)
# Requirement already satisfied: attrs>=19.2 in /usr/local/lib/python3.12/dist-packages (from cfgrib) (25.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from cfgrib) (8.3.1)
# Requirement already satisfied: eccodes>=0.9.8 in /usr/local/lib/python3.12/dist-packages (from cfgrib) (2.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from cfgrib) (2.0.2)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from eccodes>=0.9.8->cfgrib) (2.0.0)
# Requirement already satisfied: findlibs in /usr/local/lib/python3.12/dist-packages (from eccodes>=0.9.8->cfgrib) (0.1.2)
# Requirement already satisfied: eccodeslib in /usr/local/lib/python3.12/dist-packages (from eccodes>=0.9.8->cfgrib) (2.46.0.13)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->eccodes>=0.9.8->cfgrib) (3.0)
# Requirement already satisfied: eckitlib==2.0.1.13 in /usr/local/lib/python3.12/dist-packages (from eccodeslib->eccodes>=0.9.8->cfgrib) (2.0.1.13)
# Requirement already satisfied: fckitlib==0.14.2.13 in /usr/local/lib/python3.12/dist-packages (from eccodeslib->eccodes>=0.9.8->cfgrib) (0.14.2.13)

# %%
import xarray as xr
import cfgrib

# %%
#В случае этого файла нужно отдельно читать переменные для разных значений edition, иначе вылезает ошибка

ds = xr.open_dataset(
    '4aa.grib',
    engine='cfgrib',
    backend_kwargs={'filter_by_keys': {'edition': 1} }   # still fails on edition
)
# Out:
# ERROR:cfgrib.dataset:skipping variable: paramId==159 shortName='blh'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/cfgrib/dataset.py", line 726, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/usr/local/lib/python3.12/dist-packages/cfgrib/dataset.py", line 642, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='time' value=Variable(dimensions=('time',), data=array([1672509600, 1672552800, 1672596000, ..., 1767117600, 1767160800,
#        1767204000])) new_value=Variable(dimensions=('time',), data=array([1672531200, 1672534800, 1672538400, ..., 1767214800, 1767218400,
#        1767222000]))

# %%
ds.data_vars
# Out:
# Data variables:
#     tp       (time, step, latitude, longitude) float32 2MB ...
#     fdir     (time, step, latitude, longitude) float32 2MB ...
