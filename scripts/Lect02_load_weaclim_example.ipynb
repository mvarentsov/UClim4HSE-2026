# %% [markdown]
# ## Пример использования функций для парсинга данных с сайта ["Погода и климат"](https://www.pogodaiklimat.ru/)
#
# Обратите внимание, для работы необходима установка пакета lxml

# %%
from datetime import date

import pandas as pd
import weaclim_utils

# %%
station_id = '01317'      # идентификатор станции, с которой нужны наблюдения    
start = date (2023,1,1) # начало периода загрузки данных 
end = date.today()      # конец  периода загрузки данных  

weaclim_utils.load_weaclim4period (station_id, start, end, out_dir = 'weaclim_data')
# Out:
# Loading weaclim data for 1317:   0%|          | 0/37 [00:00<?, ?it/s, Processing: 2023-01]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 5
#       2 start = date (2023,1,1) # начало периода загрузки данных
#       3 end = date.today()      # конец  периода загрузки данных
# ----> 5 weaclim_utils.load_weaclim4period (station_id, start, end, out_dir = 'weaclim_data')
#
# File d:\!Work\!git\teaching\UClim4HSE-2026\scripts\weaclim_utils.py:100, in load_weaclim4period(station_id, start, end, out_dir, url)
#      97     if mod_datetime - valid_datetime > timedelta(days=31):
#      98         continue
# --> 100 df = load_weaclim4month (station_id, cur_date.year, cur_date.month, url=url)
#     101 df.to_csv(file_path)
#
# File d:\!Work\!git\teaching\UClim4HSE-2026\scripts\weaclim_utils.py:56, in load_weaclim4month(station_id, year, month, url)
#      53     raise Warning(f"Failed to process {url} with error '{err}'")
#      55 if not df0:
# ---> 56     raise Exception(f"There isn't any tabular data to read at {url}")
#      58 try:
#      59     df0 = df0[0]
#
# Exception: There isn't any tabular data to read at http://www.pogodaiklimat.ru/weather.php?id=1317&bday=1&fday=31&amonth=1&ayear=2023&bot=2

# %% [markdown]
# ## Чтение и первичный анализ загруженных данных

# %%
path = "weaclim_data/27605"

df = weaclim_utils.read_weaclim_dir (path)
# Out:
# 100%|██████████| 37/37 [00:00<00:00, 109.27it/s, reading weaclim_data/27605\27605_202601.csv]

# %%
df.head()
# Out:
#                      t2m  rh2m     slp     ps  vel10m  gust10m   tcc   lcc  \
# Datetime
# 2023-01-01 12:00:00  4.0  91.0  1004.6  989.3     1.0      NaN  10.0  10.0
# 2023-01-01 15:00:00  4.6  92.0  1003.3  988.0     1.0      NaN  10.0  10.0
# 2023-01-01 18:00:00  5.7  93.0  1001.9  986.7     1.0      NaN  10.0  10.0
# 2023-01-01 21:00:00  7.1  91.0  1001.8  986.7     2.0      NaN  10.0  10.0
# 2023-01-02 00:00:00  3.2  90.0  1003.3  988.0     2.0      NaN  10.0  10.0
#
#                      dir10m
# Datetime
# 2023-01-01 12:00:00   270.0
# 2023-01-01 15:00:00   270.0
# 2023-01-01 18:00:00   270.0
# 2023-01-01 21:00:00   270.0
# 2023-01-02 00:00:00   270.0

# %%
pd.options.plotting.backend = "plotly"

fig = df[['t2m', 'rh2m']].plot(color_discrete_map={'t2m':'red', 'rh2m':'blue'})
fig.show()
